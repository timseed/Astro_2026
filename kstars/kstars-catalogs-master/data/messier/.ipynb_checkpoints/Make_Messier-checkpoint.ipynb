# %%
from pyongc import data
import math

# %%
df=data.all()

# %%
KSTARS_TYPE_MAP = {
    # Stars
    "STAR": 1,
    "S": 1,
    "TYCHO": 1,
    # Solar system
    "PLANET": 2,
    "ASTEROID": 10,
    "COMET": 9,
    "SATELLITE": 16,
    # Clusters
    "OPEN": 3,
    "OPEN_CLUSTER": 3,
    "OC": 3,
    "GLOBULAR": 4,
    "GC": 4,
    "GLOBULAR_CLUSTER": 4,
    # Nebulae
    "GASEOUS": 5,
    "HII": 5,
    "DIFFUSE": 5,
    "EMISSION": 5,
    "PLANETARY": 6,
    "PN": 6,
    "SUPERNOVA_REMNANT": 7,
    "SNR": 7,
    # Galaxies
    "GALAXY": 8,
    "G": 8,
    "CLUSTER": 14,  # galaxy clusters
    "QUASAR": 15,
}

pyongc_mapping_to_kstars = {
         "G":KSTARS_TYPE_MAP["GALAXY"],
        "OCl":KSTARS_TYPE_MAP["OPEN_CLUSTER"],
        "Dup":KSTARS_TYPE_MAP["GALAXY"],  #Spiral 
        "*":KSTARS_TYPE_MAP["STAR"],
        "Other":KSTARS_TYPE_MAP["STAR"], # Can be Star, Nothing here 
        "**":KSTARS_TYPE_MAP["STAR"], # Double as in ** funny eh ? 
        "GPair":KSTARS_TYPE_MAP["CLUSTER"], #Galatic Pair ... so cluster ??
        "GCl":KSTARS_TYPE_MAP["CLUSTER"],
        "PN":KSTARS_TYPE_MAP["PLANETARY"],
        "Neb":KSTARS_TYPE_MAP["GASEOUS"],
        "HII":KSTARS_TYPE_MAP["HII"],
        "Cl+N":KSTARS_TYPE_MAP["DIFFUSE"],  #Star Cluster and Nebulae 
        "*Ass":KSTARS_TYPE_MAP["STAR"], #Loose cluster or stars
        "RfN":KSTARS_TYPE_MAP["GASEOUS"], #Reflection Nebulae
        "GTrpl":KSTARS_TYPE_MAP["CLUSTER"], #Galactic Triplet
        "GGroup":KSTARS_TYPE_MAP["CLUSTER"],
        "SNR":KSTARS_TYPE_MAP["SNR"],
        "NonEx":KSTARS_TYPE_MAP["STAR"], #Non Existent ... 
        "EmN":KSTARS_TYPE_MAP["EMISSION"],
        "Nova": KSTARS_TYPE_MAP["STAR"],#Nova Star
        "DrkN": KSTARS_TYPE_MAP["GASEOUS"], #Dark Nebulae
        }
df["KStars_Type"] = df["type"].map(pyongc_mapping_to_kstars)
df["ra_degrees"] = df.ra * 180.0 / math.pi
df["dec_deg"] = df["dec"].apply(math.degrees)

# %%
df_messier=df[df['messier'].str.len() > 0]

# %%
df_messier.to_csv("Messier_from_pyongc.csv")

# %%
df
# Out:
#           id       name type        ra       dec const  majax  minax     pa  \
# 0          1     IC0001   **  0.036874  0.483765   Peg    NaN    NaN    NaN
# 1          2     IC0002    G  0.048061 -0.223801   Cet   0.98   0.32  142.0
# 2          3     IC0003    G  0.052803 -0.007247   Psc   0.93   0.67   53.0
# 3          4     IC0004    G  0.058682  0.305196   Peg   1.17   0.84   12.0
# 4          5     IC0005    G  0.076717 -0.166563   Cet   0.99   0.66    9.0
# ...      ...        ...  ...       ...       ...   ...    ...    ...    ...
# 14028  14029  PGC029653    G  2.666049 -0.081904   Sex   5.25   4.47  180.0
# 14029  14030  PGC088608    G  2.674928 -0.028182   Sex  30.20  12.02   56.0
# 14030  14031   UGC04305    G  2.177660  1.234297   Cam   7.94   5.62   15.0
# 14031  14032   UGC05373    G  2.618001  0.093065   Sex   4.90   3.09  101.0
# 14032  14033   UGC05470    G  2.654944  0.214787   Leo  11.75   8.51   81.0
#
#         bmag  ...  messier  ngc  ic  cstarnames  \
# 0        NaN  ...
# 1      15.46  ...
# 2      14.78  ...
# 3      14.14  ...
# 4      14.57  ...
# ...      ...  ...      ...  ...  ..         ...
# 14028  12.32  ...
# 14029  12.00  ...
# 14030  11.16  ...
# 14031  11.92  ...
# 14032  11.16  ...
#
#                                              identifiers  \
# 0
# 1      2MASX J00110081-1249206,IRAS 00084-1306,MCG -0...
# 2      2MASX J00120604-0024543,MCG +00-01-038,PGC 000...
# 3      2MASX J00132695+1729111,IRAS 00108+1712,MCG +0...
# 4      2MASX J00173495-0932364,MCG -02-01-047,PGC 001...
# ...                                                  ...
# 14028                             MCG-01-26-030,UGCA 205
# 14029
# 14030  2MASX J08190497+7043121,IRAS 08140+7052,MCG+12...
# 14031  MCG+01-26-005,PGC 028913,SDSS J100000.82+052009.5
# 14032                           MCG+02-26-027,PGC 029488
#
#                     commonnames  \
# 0
# 1
# 2
# 3
# 4
# ...                         ...
# 14028                 Sextans A
# 14029  Sextans Dwarf Spheroidal
# 14030
# 14031                 Sextans B
# 14032                     Leo I
#
#                                                 nednotes  ongcnotes  notngc  \
# 0                                                                     False
# 1                                                                     False
# 2                                                                     False
# 3                                                                     False
# 4                                                                     False
# ...                                                  ...        ...     ...
# 14028  Position in 1975A&A....19....1G refers to a st...               True
# 14029                                                                  True
# 14030  Position in 1999ApJS..125..409C refers to a kn...               True
# 14031                                                                  True
# 14032                                                                  True
#
#        KStars_Type
# 0                1
# 1                8
# 2                8
# 3                8
# 4                8
# ...            ...
# 14028            8
# 14029            8
# 14030            8
# 14031            8
# 14032            8
#
# [14033 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['id', 'name', 'type', 'ra', 'dec', 'const', 'majax', 'minax', 'pa',
#        'bmag', 'vmag', 'jmag', 'hmag', 'kmag', 'sbrightn', 'hubble',
#        'parallax', 'pmra', 'pmdec', 'radvel', 'redshift', 'cstarumag',
#        'cstarbmag', 'cstarvmag', 'messier', 'ngc', 'ic', 'cstarnames',
#        'identifiers', 'commonnames', 'nednotes', 'ongcnotes', 'notngc',
#        'KStars_Type'],
#       dtype='object')

# %%
math.degrees(0.2)
# Out:
# 11.459155902616466
